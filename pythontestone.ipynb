# %% [markdown]
# <a href="https://colab.research.google.com/github/Icesteroidal/dukecoursecloud/blob/main/pythontestone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Python Test

# %%
print("hello world")
# Out:
# hello world
